# %%
import pandas as pd

# %%
url='https://es.wikipedia.org/wiki/Pandemia_de_enfermedad_por_coronavirus_de_2020_en_Per%C3%BA#Marzo'
df_list=pd.read_html(url)

# %%
len(df_list)
# Out:
# 10

# %%
t=df_list[8]
t.to_csv("tabla.csv",index=False)

# %%
ch=pd.read_csv("tabla.csv")
#ch=ch.drop([0,2], axis=0)
#t=ch.iloc[:,[0,27]] #iloc[:, [0,2,1]] 
#t #tabla
ch
# Out:
#            0           1        2        3            4            5  \
# 0     Semana       Fecha    Casos    Casos        Casos        Casos
# 1     Semana       Fecha  Activos  Activos  Confirmados  Confirmados
# 2     Semana       Fecha     Var.    Acum.       Nuevos        Acum.
# 3     Sem. 1    6-3-2020        1        1            1            1
# 4     Sem. 1    7-3-2020        5        6            5            6
# ..       ...         ...      ...      ...          ...          ...
# 250  Sem. 35  25-10-2020    -1343   46 930         2501      888 715
# 251  Sem. 35  26-10-2020    -1548   46 930         1859      890 574
# 252   Semana       Fecha     Var.    Acum.       Nuevos        Acum.
# 253   Semana       Fecha  Activos  Activos  Confirmados  Confirmados
# 254   Semana       Fecha    Casos    Casos        Casos        Casos
#
#                6            7           8           9     10       11  \
# ...

# %%
a=t.iloc[200:206]
a.to_csv("tmp.csv")

# %%
xls=pd.read_excel('coronavirus.xlsx') #,sheet_name=""
xls.iloc[199]

# %%
df_list[8]
# Out:
#           0           1        2        3            4            5   \
# 0     Semana       Fecha    Casos    Casos        Casos        Casos
# 1     Semana       Fecha  Activos  Activos  Confirmados  Confirmados
# 2     Semana       Fecha     Var.    Acum.       Nuevos        Acum.
# 3     Sem. 1    6-3-2020        1        1            1            1
# 4     Sem. 1    7-3-2020        5        6            5            6
# ..       ...         ...      ...      ...          ...          ...
# 250  Sem. 35  25-10-2020    -1343   46 930         2501      888 715
# 251  Sem. 35  26-10-2020    -1548   46 930         1859      890 574
# 252   Semana       Fecha     Var.    Acum.       Nuevos        Acum.
# 253   Semana       Fecha  Activos  Activos  Confirmados  Confirmados
# 254   Semana       Fecha    Casos    Casos        Casos        Casos
#
#               6            7           8           9      10       11  \
# ...
