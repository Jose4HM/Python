# %%
import pandas as pd
adult=pd.read_csv('Parte 1/adult.csv')

#adult.head()
#adult.isnull().sum() #verificar donde estan los null

adultcld=adult.fillna(0)
adultcld=adultcld.replace('?','No data')#map({'?': 'No data'}) adultcld=adultcld['workclass'] si quieres solo cambiar una columna
adultcld.to_csv('Parte 1/adult_cleaned.csv')

# %%
ad=pd.read_csv('Parte 1/adult_cleaned.csv')
df=pd.DataFrame(ad)
df.head(10)#Visualizar datos
# Out:
#    Unnamed: 0  age         workclass  fnlwgt  education  education_num  \
# 0           0   39         State-gov   77516  Bachelors             13
# 1           1   50  Self-emp-not-inc   83311  Bachelors             13
# 2           2   38           Private  215646    HS-grad              9
# 3           3   53           Private  234721       11th              7
# 4           4   28           Private  338409  Bachelors             13
# 5           5   37           Private  284582    Masters             14
# 6           6   49           Private  160187        9th              5
# 7           7   52  Self-emp-not-inc  209642    HS-grad              9
# 8           8   31           Private   45781    Masters             14
# 9           9   42           Private  159449  Bachelors             13
#
#                  marital         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# ## Resumen de tipos de datos

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital           object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_week         int64
# native_country    object
# label             object
# dtype: object

# %% [markdown]
# ## Tipos de datos

# %%
df.select_dtypes(include=['number']) #Mostraar solo los datos tipo numero
# Out:
#        Unnamed: 0  age  fnlwgt  education_num  capital_gain  capital_loss  \
# 0               0   39   77516             13          2174             0
# 1               1   50   83311             13             0             0
# 2               2   38  215646              9             0             0
# 3               3   53  234721              7             0             0
# 4               4   28  338409             13             0             0
# ...           ...  ...     ...            ...           ...           ...
# 32556       32556   27  257302             12             0             0
# 32557       32557   40  154374              9             0             0
# 32558       32558   58  151910              9             0             0
# 32559       32559   22  201490              9             0             0
# 32560       32560   52  287927              9         15024             0
#
#        hours_week
# 0              40
# 1              13
# 2              40
# ...

# %%
df.select_dtypes(include=['object']) #Mostraar solo los datos tipo objeto
# Out:
#               workclass   education             marital         occupation  \
# 0             State-gov   Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private     HS-grad            Divorced  Handlers-cleaners
# 3               Private        11th  Married-civ-spouse  Handlers-cleaners
# 4               Private   Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...         ...                 ...                ...
# 32556           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32557           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32558           Private     HS-grad             Widowed       Adm-clerical
# 32559           Private     HS-grad       Never-married       Adm-clerical
# 32560      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race     sex native_country  label
# ...

# %%
df.count() #Conteo de datos de cada columna
# Out:
# Unnamed: 0        32561
# age               32561
# workclass         32561
# fnlwgt            32561
# education         32561
# education_num     32561
# marital           32561
# occupation        32561
# relationship      32561
# race              32561
# sex               32561
# capital_gain      32561
# capital_loss      32561
# hours_week        32561
# native_country    32561
# label             32561
# dtype: int64

# %%
df.max() #Valore maximos
# Out:
# Unnamed: 0                   32560
# age                             90
# workclass              Without-pay
# fnlwgt                     1484705
# education             Some-college
# education_num                   16
# marital                    Widowed
# occupation        Transport-moving
# relationship                  Wife
# race                         White
# sex                           Male
# capital_gain                 99999
# capital_loss                  4356
# hours_week                      99
# native_country          Yugoslavia
# label                         >50K
# dtype: object

# %%
df.min() #Valores minimos
# Out:
# Unnamed: 0                         0
# age                               17
# workclass                Federal-gov
# fnlwgt                         12285
# education                       10th
# education_num                      1
# marital                     Divorced
# occupation              Adm-clerical
# relationship                 Husband
# race              Amer-Indian-Eskimo
# sex                           Female
# capital_gain                       0
# capital_loss                       0
# hours_week                         1
# native_country              Cambodia
# label                          <=50K
# dtype: object

# %%
df.median() #Mediana de cada columna solo tipo numero
# Out:
# Unnamed: 0        16280.0
# age                  37.0
# fnlwgt           178356.0
# education_num        10.0
# capital_gain          0.0
# capital_loss          0.0
# hours_week           40.0
# dtype: float64

# %% [markdown]
# ## Group by

# %%
#mostrar todos los groupby cambiando el nombre de la columna y la variable donde se guardo el group by
for education, education_df in ed:
    print(education_df)
# Out:
#        Unnamed: 0  age    workclass  fnlwgt education  education_num  \
# 77             77   67      No data  212759      10th              6
# 106           106   17      No data  304873      10th              6
# 219           219   25      Private  255004      10th              6
# 226           226   60      No data   24215      10th              6
# 252           252   59    Local-gov  171328      10th              6
# ...           ...  ...          ...     ...       ...            ...
# 32505       32505   33      Private  182401      10th              6
# 32508       32508   45      Private  155093      10th              6
# 32515       32515   66  Federal-gov   47358      10th              6
# 32526       32526   32      Private  211349      10th              6
# 32551       32551   32      Private   34066      10th              6
#
#                   marital         occupation   relationship  \
# 77     Married-civ-spouse            No data        Husband
# ...

# %%
wk.get_group('No data') #Otra forma de mostrar la agrupacion,entre parentsis va como lo vas a agrupar
# Out:
#        Unnamed: 0  age workclass  fnlwgt     education  education_num  \
# 27             27   54   No data  180211  Some-college             10
# 61             61   32   No data  293936       7th-8th              4
# 69             69   25   No data  200681  Some-college             10
# 77             77   67   No data  212759          10th              6
# 106           106   17   No data  304873          10th              6
# ...           ...  ...       ...     ...           ...            ...
# 32530       32530   35   No data  320084     Bachelors             13
# 32531       32531   30   No data   33811     Bachelors             13
# 32539       32539   71   No data  287372     Doctorate             16
# 32541       32541   41   No data  202822       HS-grad              9
# 32542       32542   72   No data  129912       HS-grad              9
#
#                      marital occupation   relationship                race  \
# ...

# %% [markdown]
# ## Graficas

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
wk=df.groupby('workclass')['age'].mean().plot(kind='bar',
    legend='Reverse',color=('red'),figsize=(20,10),fontsize=20)

plt.ylabel=("Age's amount")
plt.xlabel=('Workclass')
plt.figtext(.3,.9,"Age's amount and kind of jobs",fontsize=30)
# Out:
# Text(0.3, 0.9, "Age's amount and kind of jobs")

# %%
#sex y promedio por edad
df.age.groupby(df.sex).mean().plot(kind='pie',
    explode=(0,0.1),colors=('red','yellow'),autopct='%0.1f ',shadow=True,figsize=(20,10),fontsize=30)

plt.axis('equal')

plt.figtext(.45,.9,"Age's amount between men and women",fontsize=40)
# Out:
# Text(0.45, 0.9, "Age's amount between men and women")

# %%
#dispersion:age-education_num
my_plot=ad.plot("education_num","age",kind="scatter",color='green',figsize=(20,10),fontsize=20)

plt.figtext(.35,.9,"Age vs Education num",fontsize=40)
plt.ylabel=("Education num")
plt.xlabel=("Age")

# %%
df.groupby('age')['hours_week'].mean().plot(kind='line',
                                            figsize=(20,10),color=('green'),fontsize=20)
plt.grid(color='lightblue')
plt.ylabel=('Hours per week')
plt.xlabel=('Age')
plt.figtext(.3,.9,"Age's amount-hours per week",fontsize=40)
# Out:
# Text(0.3, 0.9, "Age's amount-hours per week")

# %% [markdown]
# ## Agrupaciones por columnas

# %%
c1=np.arange(9,dtype=np.double)
c=np.full_like(c1,0.05)
df.groupby('workclass')['workclass'].count().plot(kind='pie',
    explode=c,autopct='%0.1f %%',figsize=(20,10),shadow=True,fontsize=20)

plt.figtext(.3,.9,"Total workclass",fontsize=40)
plt.axis('equal')
# Out:
# (-1.1563305432515771,
#  1.1550633114155668,
#  -1.1104573820226946,
#  1.1127346306217194)

# %%
d1=np.arange(5,dtype=np.double)
d=np.full_like(d1,0.05)
df.groupby('race')['race'].count().plot(kind='pie',
                autopct=('%0.1f %%'),cmap='jet',explode=d,shadow=True,figsize=(20,10),fontsize=15)
plt.figtext(.45,.9,'Race',fontsize=40)
plt.axis('equal')
plt.ylabel=("Percentage per race")

# %%
df.groupby('sex')['sex'].count().plot(kind='pie',
                        autopct=('%0.1f %%'),cmap='viridis',explode=(0.1,0.1),shadow=True,figsize=(20,10),fontsize=30)
plt.axis('equal')
plt.figtext(.4,.9,'Sex by groups',fontsize=30)
plt.ylabel=("Percentage per race")

# %%
df.groupby('age')['age'].count().plot(kind='bar',figsize=(20,10),color=('purple'),fontsize=10)

plt.figtext(.35,.9,'Cantidad de datos por edades',fontsize=30)
plt.ylabel=("Total de datos")
plt.xlabel=('Edades')

# %%
df.groupby('education')['education'].count().plot(kind='bar',figsize=(20,10),color=('orange'),fontsize=20)

plt.figtext(.4,.9,'Grade of education',fontsize=30)
plt.ylabel=("Total")
plt.xlabel=('Grade of education')

# %%
df.groupby('education_num')['education_num'].count().plot(kind='barh',figsize=(15,10),color=('crimson'),fontsize=20
                                                         )
plt.figtext(.35,.9,"Education's number",fontsize=30)
plt.ylabel=("Grade")
plt.xlabel=('Total')

# %%
a1=np.arange(7,dtype=np.double)
a=np.full_like(a1,0.05)

df.groupby('marital')['marital'].count().plot(kind='pie',
            figsize=(20,10),autopct='%0.1f %%',cmap=('spring'),explode=a,shadow=True,fontsize=20)

plt.figtext(.5,.9,'Marital situation',fontsize=30)
# Out:
# Text(0.5, 0.9, 'Marital situation')

# %%
x=np.arange(15,dtype=np.double)
k=np.full_like(x,0.1)
df.groupby('occupation')['occupation'].count().plot(kind='pie',
            figsize=(20,10),cmap=('winter'),explode=k,shadow=True,autopct='%0.1f %%',fontsize=20)

plt.figtext(.5,.9,'Occupation',fontsize=30)
# Out:
# Text(0.5, 0.9, 'Occupation')

# %%
b=np.arange(6,dtype=np.double)
b1=np.full_like(b,0.1)
df.groupby('relationship')['relationship'].count().plot(kind='pie',
            figsize=(20,10),cmap=('winter'),explode=b1,shadow=True,autopct='%0.1f %%',fontsize=20)

plt.figtext(.5,.9,'Relatioship',fontsize=30)
plt.ylabel=('')

# %%
df.groupby('native_country')['native_country'].count().plot(kind='bar',fontsize=20,
            figsize=(20,10),color=('cyan'))

plt.figtext(.4,.9,'Native country',fontsize=30)
plt.xlabel=('Country')
plt.ylabel=('Sum')

# %%
df.groupby('hours_week')['hours_week'].count().plot(kind='line',fontsize=20,
            figsize=(20,10),color=('gold'))
plt.xlabel=('Hours')
plt.ylabel=('NUmber of Persons')
plt.figtext(.4,.9,'Hours per week',fontsize=30)
plt.legend()

# %%
wk=df.groupby('education')['capital_gain'].mean().plot(kind='bar',fontsize=20,
    legend='Reverse',color=('green'),figsize=(15,10))

plt.figtext(.3,.9,'Education with capital gained',fontsize=30)
plt.ylabel=('education')
plt.xlabel=('capital gain')
